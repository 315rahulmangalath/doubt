# %% [markdown]
# Grades of Students dataset
#
# Problem Statement:
#
# The dataset contains grades scored by students throughout their university tenure in various courses and their CGPA calculated based on their grades
#
#
# Columns Description    --  total 43 columns
# -Seat No : The enrolled number of candidate that took the exams
#
# -
#
# CGPA : The cumulative GPA based on the four year total grade progress of each candidate . CGPA is a Final Marks -- provided to student.
#
#
#
# ·       All other columns are course codes in the format AB-XXX where AB are alphabets representing candidates' departments and XXX are numbers where first X represents the year the canditate took exam
#
#
#
#
#
# Predict   CGPA of a student based on different grades in four years.

# %%
import pandas as pd
import numpy as np
#df.describe(include='o')
#df.Targetvalue_counts(normalize=True)*100
#LE.inverse_transform([1,0])

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset4/main/Grades.csv")
df.head()
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
#
#   ME-107 CS-107 HS-205/20 MT-222 EE-222 MT-224 CS-210 CS-211 CS-203 CS-214  \
# 0     C-     C-        B+      D     A-     B-     C+     D+     D+      D
# 1      D     B+        C+     B-     C-     D+     D+      D      C      D
# 2     A-     B-        A-      A      A      A      A     A+      A     A-
# 3     C+      D         B     D+     B-      D      C     B+     C+      D
# 4     A-      C         A      A     A-     A-     A-     B-      A     A-
#
# ...

# %%
df.shape
# Out:
# (571, 43)

# %%
#displating max_rows
pd.set_option('display.max_rows',None,'display.max_columns',None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   571 non-null    object
#  1   PH-121     571 non-null    object
#  2   HS-101     571 non-null    object
#  3   CY-105     570 non-null    object
#  4   HS-105/12  570 non-null    object
#  5   MT-111     569 non-null    object
#  6   CS-105     571 non-null    object
#  7   CS-106     569 non-null    object
#  8   EL-102     569 non-null    object
#  9   EE-119     569 non-null    object
#  10  ME-107     569 non-null    object
#  11  CS-107     569 non-null    object
#  12  HS-205/20  566 non-null    object
#  13  MT-222     566 non-null    object
#  14  EE-222     564 non-null    object
#  15  MT-224     564 non-null    object
#  16  CS-210     564 non-null    object
#  17  CS-211     566 non-null    object
#  18  CS-203     566 non-null    object
# ...

# %% [markdown]
# # since the target variable is continous this is Regression problem

# %% [markdown]
# we are able too see some columns data is missing so we have to fill data in these columns

# %%
df.head(10)
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
# 5  CS-97006      A     B-      B        D+     C+     A-     C+      B     B+
# 6  CS-97007     B-     C-     A-         D     A-      B      A     B+     A-
# 7  CS-97008     B+     B+     C+         C      C     A-     C-     A-      B
# 8  CS-97009     A-      C     A-        D+      B     A-     A-     A-     B+
# 9  CS-97010      A      B     C+         B      B     A-      C     B-     A-
#
#   ME-107 CS-107 HS-205/20 MT-222 EE-222 MT-224 CS-210 CS-211 CS-203 CS-214  \
# ...

# %% [markdown]
# # Missing values

# %%
#replacing empt cells with null values
#df["CY-105"] = df["CY-105"].replace(' ', np.nan)

# %%
df.columns
# Out:
# Index(['Seat No.', 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111',
#        'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
#        'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
#        'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
#        'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
#        'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
#        'CS-412', 'CGPA'],
#       dtype='object')

# %%
#seperating the columns with nul value
columns=['CY-105', 'HS-105/12', 'MT-111',
       'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
       'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
       'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
       'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
       'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
       'CS-412']

# %%
len(columns)
# Out:
# 39

# %%
#filling null values with mode in each column
for i in range(39):
    df[columns[i]].fillna(df[columns[i]].mode()[0], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   571 non-null    object
#  1   PH-121     571 non-null    object
#  2   HS-101     571 non-null    object
#  3   CY-105     571 non-null    object
#  4   HS-105/12  571 non-null    object
#  5   MT-111     571 non-null    object
#  6   CS-105     571 non-null    object
#  7   CS-106     571 non-null    object
#  8   EL-102     571 non-null    object
#  9   EE-119     571 non-null    object
#  10  ME-107     571 non-null    object
#  11  CS-107     571 non-null    object
#  12  HS-205/20  571 non-null    object
#  13  MT-222     571 non-null    object
#  14  EE-222     571 non-null    object
#  15  MT-224     571 non-null    object
#  16  CS-210     571 non-null    object
#  17  CS-211     571 non-null    object
#  18  CS-203     571 non-null    object
# ...

# %% [markdown]
# we have filled blank cells with null values,lets fillthe missing values in each columns next

# %%
df.CGPA.value_counts()
# Out:
# 3.019    5
# 3.058    3
# 2.793    3
# 3.443    3
# 2.206    3
# 2.756    3
# 3.772    3
# 2.605    2
# 3.023    2
# 3.010    2
# 2.895    2
# 2.352    2
# 3.451    2
# 3.651    2
# 3.481    2
# 3.769    2
# 2.999    2
# 2.880    2
# 3.189    2
# 2.028    2
# 3.334    2
# 2.659    2
# 2.779    2
# 2.311    2
# 3.229    2
# 3.094    2
# 3.607    2
# 3.919    2
# 3.335    2
# 3.226    2
# 3.942    2
# 2.084    2
# 3.876    2
# 2.612    2
# 2.378    2
# 3.477    2
# 2.931    2
# 2.763    2
# 3.759    2
# 1.992    2
# 3.137    2
# 3.491    2
# 3.714    2
# 3.339    2
# 3.068    2
# 3.043    2
# 3.365    2
# 3.798    2
# 2.982    2
# 3.156    2
# 2.086    2
# 2.188    2
# 3.195    2
# 3.476    2
# 2.603    2
# 3.369    2
# 3.625    2
# 2.328    2
# 3.523    2
# 3.182    2
# 2.947    2
# 3.164    2
# 3.332    2
# 2.484    2
# 1.886    2
# 3.033    2
# 3.114    2
# 2.851    2
# 2.918    2
# 2.619    2
# 3.765    2
# 2.559    1
# 3.618    1
# 2.321    1
# 2.451    1
# 2.512    1
# ...

# %% [markdown]
# # we have removed the null values from the data set lets moce in with the EDA

# %%
#  col=['Seat No.', 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111',
#       'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
#       'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
#       'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
#       'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
#      'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
#      'CS-412']
""""""
# Out:
# ''

# %%
len(col)
# Out:
# 42

# %% [markdown]
# we have successfully encoded al the data columns

# %%
#encoding Name
#df["PH-121"]=OE.fit_transform(df["PH-121"].values.reshape(-1,1))

# %%
#df["PH-121"].unique()
# Out:
# array([ 5.,  0.,  9.,  2.,  4.,  3.,  7.,  6.,  8., 10., 12.,  1., 11.])

# %%
col=['Seat No.', 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111',
       'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
       'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
       'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
       'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
       'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
       'CS-412']

# %%
len(col)
# Out:
# 42

# %%
df[col[1]].unique()
# Out:
# array(['B-', 'A', 'D', 'A-', 'B+', 'B', 'C+', 'C', 'C-', 'D+', 'WU', 'A+',
#        'F'], dtype=object)

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
ord_enc = OrdinalEncoder(categories=[['WU','F','D+','D', 'C-','C','C+','B-', 'B','B+','A-', 'A','A+']])

# %%
Encoded_df = ord_enc.fit_transform(df[[ 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111',
       'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
       'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
       'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
       'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
       'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
       'CS-412']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [83], in <cell line: 1>()
# ----> 1 Encoded_df = ord_enc.fit_transform(df[[ 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111',
#       2        'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
#       3        'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
#       4        'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
#       5        'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
#       6        'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
#       7        'CS-412']])
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:867, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     863 # non-optimized default implementation; override when a better
# ...

# %%
for i in range(42):
    df[col[i]]=OE.fit_transform(df[col[i]].values.reshape(-1,1))
df.shape
# Out:
# (571, 43)

# %%
df["PH-121"].unique()
# Out:
# array([ 5.,  0.,  9.,  2.,  4.,  3.,  7.,  6.,  8., 10., 12.,  1., 11.])

# %% [markdown]
# # statistics summary

# %%
df.describe().T
# Out:
#            count        mean         std  min      25%      50%      75%  \
# Seat No.   571.0  285.000000  164.977776  0.0  142.500  285.000  427.500
# PH-121     571.0    3.781086    3.046895  0.0    2.000    3.000    6.000
# HS-101     571.0    5.071804    2.785317  0.0    3.000    5.000    7.000
# CY-105     570.0    2.903509    2.964848  0.0    0.000    2.000    4.750
# HS-105/12  570.0    4.249123    3.198370  0.0    2.000    4.000    7.000
# MT-111     569.0    3.903339    2.991680  0.0    2.000    4.000    6.000
# CS-105     571.0    2.838879    2.696709  0.0    0.000    2.000    4.000
# CS-106     569.0    4.130053    2.729074  0.0    2.000    4.000    5.000
# EL-102     569.0    3.966608    3.034533  0.0    2.000    3.000    6.000
# EE-119     569.0    3.892794    2.659841  0.0    2.000    3.000    6.000
# ME-107     569.0    4.789104    3.147403  0.0    2.000    5.000    8.000
# CS-107     569.0    4.082601    3.257472  0.0    1.000    4.000    7.000
# ...
