# %% [markdown]
# Problem Statement:
# Context
#
# The World Happiness Report is a landmark survey of the state of global happiness. The first report was published in 2012, the second in 2013, the third in 2015, and the fourth in the 2016 Update. The World Happiness 2017, which ranks 155 countries by their happiness levels, was released at the United Nations at an event celebrating International Day of Happiness on March 20th. The report continues to gain global recognition as governments, organizations and civil society increasingly use happiness indicators to inform their policy-making decisions. Leading experts across fields – economics, psychology, survey analysis, national statistics, health, public policy and more – describe how measurements of well-being can be used effectively to assess the progress of nations. The reports review the state of happiness in the world today and show how the new science of happiness explains personal and national variations in happiness.

# %%
#importing necessary libraries

import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pylab as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv")
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %% [markdown]
# Since the data of Target variable is continuous it's a regression problem.

# %% [markdown]
# # EDA

# %%
df.describe().T
# Out:
#                                count       mean        std      min  \
# Happiness Rank                 158.0  79.493671  45.754363  1.00000
# Happiness Score                158.0   5.375734   1.145010  2.83900
# Standard Error                 158.0   0.047885   0.017146  0.01848
# Economy (GDP per Capita)       158.0   0.846137   0.403121  0.00000
# Family                         158.0   0.991046   0.272369  0.00000
# Health (Life Expectancy)       158.0   0.630259   0.247078  0.00000
# Freedom                        158.0   0.428615   0.150693  0.00000
# Trust (Government Corruption)  158.0   0.143422   0.120034  0.00000
# Generosity                     158.0   0.237296   0.126685  0.00000
# Dystopia Residual              158.0   2.098977   0.553550  0.32858
#
#                                      25%        50%         75%        max
# Happiness Rank                 40.250000  79.500000  118.750000  158.00000
# Happiness Score                 4.526000   5.232500    6.243750    7.58700
# Standard Error                  0.037268   0.043940    0.052300    0.13693
# Economy (GDP per Capita)        0.545808   0.910245    1.158448    1.69042
# Family                          0.856823   1.029510    1.214405    1.40223
# Health (Life Expectancy)        0.439185   0.696705    0.811013    1.02525
# Freedom                         0.328330   0.435515    0.549092    0.66973
# Trust (Government Corruption)   0.061675   0.107220    0.180255    0.55191
# Generosity                      0.150553   0.216130    0.309883    0.79588
# Dystopia Residual               1.759410   2.095415    2.462415    3.60214

# %%
df.shape
# Out:
# (158, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB

# %% [markdown]
# Here we can analyse that country and region are object type data, happiness rank is integer type and all other left out data is float type data.

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# there is no nul values present inside the dataset

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.Region.unique()
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia'], dtype=object)

# %% [markdown]
# # Univariate Analysis

# %%
# let's see how data is distributed for every column after power transformer
plt.figure(figsize=(20,65), facecolor='white')
plotno = 1

for column in df.columns:
    if (2<plotno<=13) :
        ax = plt.subplot(6,2,plotno)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
       
    plotno+=1
plt.show()

# %% [raw]
# Happiness rank,happiness score,Distopia residual are  normally distributed.
#
# genorisity,Trust,Standard error looks right skewed
#
# economy,family,Health,Freedom  looks left skewed

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LE=LabelEncoder()
categ = ['Country', 'Region']

df[categ] = df[categ].apply(LE.fit_transform)

# %%
df.head()
# Out:
#    Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135       9               1            7.587         0.03411
# 1       58       9               2            7.561         0.04884
# 2       37       9               3            7.527         0.03328
# 3      105       9               4            7.522         0.03880
# 4       24       5               5            7.427         0.03553
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.41978     0.29678            2.51738
# 1                        0.14145     0.43630            2.70201
# 2                        0.48357     0.34139            2.49204
# 3                        0.36503     0.34699            2.46531
# 4                        0.32957     0.45811            2.45176

# %% [markdown]
# # Identifying outliers

# %%
df.plot(kind='box',fontsize=14,figsize=(30,10),color='r')
# Out:
# <AxesSubplot:>

# %%
# let's identify outliers for every column
plt.figure(figsize=(20,20), facecolor='white')
plotno = 1

for column in df.columns:
    if (plotno<=13) :
        ax = plt.subplot(6,2,plotno)
        sns.boxplot(df[column])
        plt.xlabel(column,fontsize=12)
       
    plotno+=1
plt.show()

# %% [markdown]
# we are able to observe outliers in multiple columns

# %%
from scipy.stats import zscore
zsco=np.abs(zscore(df))
df_new=df[(zsco<3).all(axis=1)]

# %%
df_new.shape
# Out:
# (149, 12)

# %%
df.shape
# Out:
# (158, 12)

# %%
((9/158)*100)
# Out:
# 5.69620253164557

# %%
df
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587         0.03411
# 1         58       9               2            7.561         0.04884
# 2         37       9               3            7.527         0.03328
# 3        105       9               4            7.522         0.03880
# 4         24       5               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 153      118       8             154            3.465         0.03464
# 154       13       8             155            3.340         0.03656
# 155      136       4             156            3.006         0.05015
# 156       21       8             157            2.905         0.08658
# 157      141       8             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# 3                     1.45900  1.33095                   0.88521  0.66973
# 4                     1.32629  1.32261                   0.90563  0.63297
# ..                        ...      ...                       ...      ...
# 153                   0.22208  0.77370                   0.42864  0.59201
# 154                   0.28665  0.35386                   0.31910  0.48450
# 155                   0.66320  0.47489                   0.72193  0.15684
# 156                   0.01530  0.41587                   0.22396  0.11850
# 157                   0.20868  0.13995                   0.28443  0.36453
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                          0.41978     0.29678            2.51738
# 1                          0.14145     0.43630            2.70201
# 2                          0.48357     0.34139            2.49204
# 3                          0.36503     0.34699            2.46531
# 4                          0.32957     0.45811            2.45176
# ..                             ...         ...                ...
# 153                        0.55191     0.22628            0.67042
# 154                        0.08010     0.18260            1.63328
# 155                        0.18906     0.47179            0.32858
# 156                        0.10062     0.19727            1.83302
# 157                        0.10731     0.16681            1.56726
#
# [158 rows x 12 columns]

# %%
df_new
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587         0.03411
# 1         58       9               2            7.561         0.04884
# 2         37       9               3            7.527         0.03328
# 3        105       9               4            7.522         0.03880
# 4         24       5               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 150       66       8             151            3.655         0.05141
# 151       20       8             152            3.587         0.04324
# 152        0       7             153            3.575         0.03084
# 154       13       8             155            3.340         0.03656
# 156       21       8             157            2.905         0.08658
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# 3                     1.45900  1.33095                   0.88521  0.66973
# 4                     1.32629  1.32261                   0.90563  0.63297
# ..                        ...      ...                       ...      ...
# 150                   0.46534  0.77115                   0.15185  0.46866
# 151                   0.25812  0.85188                   0.27125  0.39493
# 152                   0.31982  0.30285                   0.30335  0.23414
# 154                   0.28665  0.35386                   0.31910  0.48450
# 156                   0.01530  0.41587                   0.22396  0.11850
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                          0.41978     0.29678            2.51738
# 1                          0.14145     0.43630            2.70201
# 2                          0.48357     0.34139            2.49204
# 3                          0.36503     0.34699            2.46531
# 4                          0.32957     0.45811            2.45176
# ..                             ...         ...                ...
# 150                        0.17922     0.20165            1.41723
# 151                        0.12832     0.21747            1.46494
# 152                        0.09719     0.36510            1.95210
# 154                        0.08010     0.18260            1.63328
# 156                        0.10062     0.19727            1.83302
#
# [149 rows x 12 columns]

# %% [markdown]
# The data loss is less than 10% in zscore method

# %% [markdown]
# # using heatmap

# %%
plt.figure(figsize=(24,22))
sns.heatmap(df.corr(),annot=True
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(22,15))
df_new.corr()['Dystopia Residual'].sort_values(ascending=False).drop(['Dystopia Residual']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=20)
plt.ylabel('column with target ',fontsize=20)
plt.title('correlation',fontsize=18)
plt.show()

# %%
X=df.drop('Dystopia Residual',axis=1)

# %%
y=df['Dystopia Residual']

# %%
X.skew().sort_values(ascending=False)
# Out:
# Standard Error                   1.983439
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Happiness Score                  0.097769
# Happiness Rank                   0.000418
# Country                          0.000000
# Region                          -0.116119
# Economy (GDP per Capita)        -0.317575
# Freedom                         -0.413462
# Health (Life Expectancy)        -0.705328
# Family                          -1.006893
# dtype: float64

# %%
from sklearn.preprocessing import power_transform
X_new=power_transform(X)

# %%
X = pd.DataFrame(X_new,columns=X.columns)

# %%
X.skew().sort_values(ascending=False)
# Out:
# Trust (Government Corruption)    0.185965
# Generosity                       0.013320
# Standard Error                  -0.020092
# Happiness Score                 -0.027956
# Freedom                         -0.080728
# Economy (GDP per Capita)        -0.127233
# Family                          -0.169651
# Health (Life Expectancy)        -0.183181
# Region                          -0.228041
# Happiness Rank                  -0.264365
# Country                         -0.279791
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

# %%
X_scaled.shape
# Out:
# (158, 11)

# %%
X_scaled.shape[1]
# Out:
# 11

# %% [markdown]
# the skewness has been removed

# %% [markdown]
# # lets check for multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif["vif"]=[variance_inflation_factor(X_scaled,i) for i in range(X_scaled.shape[1])]
vif["features"]=X.columns

# %%
vif
# Out:
#           vif                       features
# 0    1.041379                        Country
# 1    1.367526                         Region
# 2   56.777733                 Happiness Rank
# 3   54.607503                Happiness Score
# 4    1.172650                 Standard Error
# 5    4.813846       Economy (GDP per Capita)
# 6    2.787659                         Family
# 7    4.409107       Health (Life Expectancy)
# 8    2.117970                        Freedom
# 9    1.515871  Trust (Government Corruption)
# 10   1.455893                     Generosity

# %% [markdown]
# we can remove the Happiness Rank as it is>5

# %%
X=X.drop('Happiness Rank',axis=1)

# %%
X.columns
# Out:
# Index(['Country', 'Region', 'Happiness Score', 'Standard Error',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity'],
#       dtype='object')

# %%
X_scaled=scaler.fit_transform(X)

# %%
vif=pd.DataFrame()
vif["vif"]=[variance_inflation_factor(X_scaled,i) for i in range(X_scaled.shape[1])]
vif["features"]=X.columns
vif
# Out:
#         vif                       features
# 0  1.041259                        Country
# 1  1.361651                         Region
# 2  4.676400                Happiness Score
# 3  1.171690                 Standard Error
# 4  4.813532       Economy (GDP per Capita)
# 5  2.781766                         Family
# 6  4.328448       Health (Life Expectancy)
# 7  2.102786                        Freedom
# 8  1.456431  Trust (Government Corruption)
# 9  1.453946                     Generosity

# %% [markdown]
# since vif score is less than 5 this is allowable let move on with the data

# %%
#importing necessary libraries
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import r2_score

# %%
#Selecting best random state

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=i)
    LR=LinearRegression()
    LR.fit(x_train,y_train)
    
    pred_lr_train=LR.predict(x_train)
    pred_lr_test=LR.predict(x_test)
    
    print(f"At random state{i},the training accuracy is :-",r2_score(y_train,pred_lr_train)*100)
    print(f"At random state{i},the testing accuracy is :- ",r2_score(y_test,pred_lr_test)*100)
    print("\n")
# Out:
# At random state0,the training accuracy is :- 95.57621950773162
# At random state0,the testing accuracy is :-  96.27023986939707
#
#
# At random state1,the training accuracy is :- 96.23889289271466
# At random state1,the testing accuracy is :-  91.80730281672487
#
#
# At random state2,the training accuracy is :- 95.10595458172052
# At random state2,the testing accuracy is :-  97.77732781869963
#
#
# At random state3,the training accuracy is :- 95.75748867825882
# At random state3,the testing accuracy is :-  95.45875105730462
#
#
# At random state4,the training accuracy is :- 95.11553237740846
# At random state4,the testing accuracy is :-  97.66862679190852
#
#
# At random state5,the training accuracy is :- 95.7374717796264
# At random state5,the testing accuracy is :-  95.36680610288602
#
#
# At random state6,the training accuracy is :- 95.50661562598405
# At random state6,the testing accuracy is :-  97.05510091671755
#
#
# At random state7,the training accuracy is :- 96.26631643086864
# At random state7,the testing accuracy is :-  93.61638669075587
#
#
# At random state8,the training accuracy is :- 96.58198759547187
# At random state8,the testing accuracy is :-  92.79814972353007
#
#
# At random state9,the training accuracy is :- 95.59265164304003
# At random state9,the testing accuracy is :-  96.2916093702956
#
#
# At random state10,the training accuracy is :- 95.84713040693079
# At random state10,the testing accuracy is :-  95.25294789003746
#
#
# At random state11,the training accuracy is :- 95.67056121474235
# At random state11,the testing accuracy is :-  95.77106956250238
#
#
# At random state12,the training accuracy is :- 95.37678159002775
# At random state12,the testing accuracy is :-  96.87902751910859
#
#
# At random state13,the training accuracy is :- 95.97489081745158
# At random state13,the testing accuracy is :-  95.13788361004329
#
#
# At random state14,the training accuracy is :- 96.08897889250449
# At random state14,the testing accuracy is :-  93.78615606935668
#
#
# At random state15,the training accuracy is :- 96.66135751361976
# At random state15,the testing accuracy is :-  89.789279564762
#
#
# At random state16,the training accuracy is :- 96.11734269360552
# At random state16,the testing accuracy is :-  94.0736218687377
#
#
# At random state17,the training accuracy is :- 96.00169782532633
# At random state17,the testing accuracy is :-  94.11251469521356
#
#
# At random state18,the training accuracy is :- 97.33991431344181
# At random state18,the testing accuracy is :-  84.93469309606006
#
#
# At random state19,the training accuracy is :- 95.25870976077117
# At random state19,the testing accuracy is :-  98.04371138643072
#
#
# At random state20,the training accuracy is :- 95.9044345712096
# At random state20,the testing accuracy is :-  95.2417899001763
#
#
# At random state21,the training accuracy is :- 95.3949189635777
# At random state21,the testing accuracy is :-  96.70164116399333
#
#
# At random state22,the training accuracy is :- 94.66628824066576
# At random state22,the testing accuracy is :-  98.27177731156542
#
#
# At random state23,the training accuracy is :- 96.48084840037046
# At random state23,the testing accuracy is :-  90.92457460589839
#
#
# At random state24,the training accuracy is :- 96.38805587284189
# At random state24,the testing accuracy is :-  91.48139530014001
#
#
# At random state25,the training accuracy is :- 95.62500934831426
# At random state25,the testing accuracy is :-  96.39039549637846
#
#
# At random state26,the training accuracy is :- 96.42478078043379
# At random state26,the testing accuracy is :-  92.05432670546473
#
#
# At random state27,the training accuracy is :- 95.42891359664397
# At random state27,the testing accuracy is :-  96.55880687459405
#
#
# At random state28,the training accuracy is :- 95.36023613379369
# At random state28,the testing accuracy is :-  96.7827793450688
#
#
# At random state29,the training accuracy is :- 95.96340767894307
# At random state29,the testing accuracy is :-  94.9620003813227
#
#
# At random state30,the training accuracy is :- 95.53165460994362
# At random state30,the testing accuracy is :-  96.6945909162903
#
#
# At random state31,the training accuracy is :- 95.62927818547455
# At random state31,the testing accuracy is :-  95.73212754935058
#
#
# At random state32,the training accuracy is :- 95.21799785891528
# At random state32,the testing accuracy is :-  96.89458615729183
#
#
# At random state33,the training accuracy is :- 95.44477667238193
# At random state33,the testing accuracy is :-  96.0167653196282
#
#
# At random state34,the training accuracy is :- 95.83732076413304
# At random state34,the testing accuracy is :-  95.17281805154279
#
#
# At random state35,the training accuracy is :- 95.1140908450937
# At random state35,the testing accuracy is :-  97.90268814394419
#
#
# At random state36,the training accuracy is :- 95.8517601415689
# At random state36,the testing accuracy is :-  95.34700621717286
#
#
# At random state37,the training accuracy is :- 96.54628648429124
# At random state37,the testing accuracy is :-  92.32480273859083
#
#
# At random state38,the training accuracy is :- 95.43759249480487
# At random state38,the testing accuracy is :-  97.17869126047357
#
#
# At random state39,the training accuracy is :- 96.85881824903157
# At random state39,the testing accuracy is :-  90.75998014523432
#
#
# At random state40,the training accuracy is :- 95.53711437054112
# At random state40,the testing accuracy is :-  96.20538048242499
#
#
# At random state41,the training accuracy is :- 95.43074385517237
# At random state41,the testing accuracy is :-  96.3766016174878
#
#
# At random state42,the training accuracy is :- 96.20523114502762
# At random state42,the testing accuracy is :-  93.34727721465741
#
#
# At random state43,the training accuracy is :- 95.2012499574693
# At random state43,the testing accuracy is :-  97.02828805406838
#
#
# At random state44,the training accuracy is :- 96.14191817054278
# At random state44,the testing accuracy is :-  93.77053319403507
#
#
# At random state45,the training accuracy is :- 95.88095428662349
# At random state45,the testing accuracy is :-  95.21892611476669
#
#
# At random state46,the training accuracy is :- 95.88849834354411
# At random state46,the testing accuracy is :-  95.25683810929463
#
#
# At random state47,the training accuracy is :- 95.81507477829247
# At random state47,the testing accuracy is :-  94.97594187185646
#
#
# At random state48,the training accuracy is :- 94.12803956413941
# At random state48,the testing accuracy is :-  98.4982052972434
#
#
# At random state49,the training accuracy is :- 95.8289355281674
# At random state49,the testing accuracy is :-  95.2397986155757
#
#
# At random state50,the training accuracy is :- 95.81813559504151
# At random state50,the testing accuracy is :-  95.10578346813416
#
#
# At random state51,the training accuracy is :- 95.7434130543881
# At random state51,the testing accuracy is :-  95.57239313973436
#
#
# At random state52,the training accuracy is :- 96.51253458849928
# At random state52,the testing accuracy is :-  88.08163728691538
#
#
# At random state53,the training accuracy is :- 95.0981449635774
# At random state53,the testing accuracy is :-  97.02357232936023
#
#
# At random state54,the training accuracy is :- 96.8605941242191
# At random state54,the testing accuracy is :-  89.86524008058974
#
#
# At random state55,the training accuracy is :- 95.82716824719165
# At random state55,the testing accuracy is :-  95.55013509535169
#
#
# At random state56,the training accuracy is :- 96.49487365481261
# At random state56,the testing accuracy is :-  91.28026691268877
#
#
# At random state57,the training accuracy is :- 95.72009875336019
# At random state57,the testing accuracy is :-  95.49166234799347
#
#
# At random state58,the training accuracy is :- 95.8464060343371
# At random state58,the testing accuracy is :-  95.09050045899488
#
#
# At random state59,the training accuracy is :- 95.15731822831961
# At random state59,the testing accuracy is :-  96.57501300418205
#
#
# At random state60,the training accuracy is :- 96.69117358771845
# At random state60,the testing accuracy is :-  92.65217570549676
#
#
# At random state61,the training accuracy is :- 96.33022148707222
# At random state61,the testing accuracy is :-  92.19892959795993
#
#
# At random state62,the training accuracy is :- 95.59679524246715
# At random state62,the testing accuracy is :-  96.35830684224642
#
#
# At random state63,the training accuracy is :- 95.59394118638365
# At random state63,the testing accuracy is :-  95.45032731837355
#
#
# At random state64,the training accuracy is :- 96.56556368946073
# At random state64,the testing accuracy is :-  92.78311590238496
#
#
# At random state65,the training accuracy is :- 96.05073333697078
# At random state65,the testing accuracy is :-  94.91820996701551
#
#
# At random state66,the training accuracy is :- 96.57922386833307
# At random state66,the testing accuracy is :-  90.94389324542125
#
#
# At random state67,the training accuracy is :- 97.47267073265348
# At random state67,the testing accuracy is :-  84.06395195562271
#
#
# At random state68,the training accuracy is :- 95.58160872067037
# At random state68,the testing accuracy is :-  96.85876083714078
#
#
# At random state69,the training accuracy is :- 96.23972615333722
# At random state69,the testing accuracy is :-  93.28942244212027
#
#
# At random state70,the training accuracy is :- 95.32319669098439
# At random state70,the testing accuracy is :-  97.2204564521726
#
#
# At random state71,the training accuracy is :- 95.48586558109898
# At random state71,the testing accuracy is :-  96.83647648895239
#
#
# At random state72,the training accuracy is :- 97.59155009413988
# At random state72,the testing accuracy is :-  81.89363031832436
#
#
# At random state73,the training accuracy is :- 96.4071940541016
# At random state73,the testing accuracy is :-  92.86329301769337
#
#
# At random state74,the training accuracy is :- 96.46205218047842
# At random state74,the testing accuracy is :-  92.86540364568872
#
#
# At random state75,the training accuracy is :- 95.39659890594473
# At random state75,the testing accuracy is :-  96.7112926040202
#
#
# At random state76,the training accuracy is :- 95.02726793503572
# At random state76,the testing accuracy is :-  98.12161504405572
#
#
# At random state77,the training accuracy is :- 95.1227423083854
# At random state77,the testing accuracy is :-  97.83697722355318
#
#
# At random state78,the training accuracy is :- 94.9051322375527
# At random state78,the testing accuracy is :-  97.31810971045742
#
#
# At random state79,the training accuracy is :- 96.35469442237674
# At random state79,the testing accuracy is :-  93.825569040464
#
#
# At random state80,the training accuracy is :- 95.83067835037843
# At random state80,the testing accuracy is :-  95.37421071235586
#
#
# At random state81,the training accuracy is :- 95.77402154413302
# At random state81,the testing accuracy is :-  95.06491629715212
#
#
# At random state82,the training accuracy is :- 94.97991665539158
# At random state82,the testing accuracy is :-  98.63442081129912
#
#
# At random state83,the training accuracy is :- 96.91261655388921
# At random state83,the testing accuracy is :-  92.2530897677138
#
#
# At random state84,the training accuracy is :- 96.16279858963208
# At random state84,the testing accuracy is :-  93.32658933041431
#
#
# At random state85,the training accuracy is :- 95.53731212300627
# At random state85,the testing accuracy is :-  95.685676373603
#
#
# At random state86,the training accuracy is :- 96.47674603342182
# At random state86,the testing accuracy is :-  92.05291146256452
#
#
# At random state87,the training accuracy is :- 95.3395669305704
# At random state87,the testing accuracy is :-  97.14371441297887
#
#
# At random state88,the training accuracy is :- 96.06545920523062
# At random state88,the testing accuracy is :-  93.95910995449847
#
#
# At random state89,the training accuracy is :- 94.50432279665087
# At random state89,the testing accuracy is :-  98.38915192454539
#
#
# At random state90,the training accuracy is :- 95.8344523472011
# At random state90,the testing accuracy is :-  95.57253431636433
#
#
# At random state91,the training accuracy is :- 95.54224662825867
# At random state91,the testing accuracy is :-  96.2277513011897
#
#
# At random state92,the training accuracy is :- 95.93029294552889
# At random state92,the testing accuracy is :-  94.67511349191618
#
#
# At random state93,the training accuracy is :- 95.74038844826062
# At random state93,the testing accuracy is :-  95.6193845726532
#
#
# At random state94,the training accuracy is :- 96.2009774940006
# At random state94,the testing accuracy is :-  92.71641899054158
#
#
# At random state95,the training accuracy is :- 95.81887585184192
# At random state95,the testing accuracy is :-  95.19470155054412
#
#
# At random state96,the training accuracy is :- 95.02710368522068
# At random state96,the testing accuracy is :-  98.30431489116619
#
#
# At random state97,the training accuracy is :- 95.31520908986074
# At random state97,the testing accuracy is :-  97.79450213047885
#
#
# At random state98,the training accuracy is :- 95.3773657194216
# At random state98,the testing accuracy is :-  97.09833442279411
#
#
# At random state99,the training accuracy is :- 95.47353157424021
# At random state99,the testing accuracy is :-  95.86971046561864

# %% [markdown]
# we will choose random state 11 with least difference in training and testing accuracy

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=.02, random_state =11)

# %%
#importing necessary libraries
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor 
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score

# %% [markdown]
# # 1)LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
pred_lr = lr.predict(x_test)
print("accuracy of the model =",(r2_score(y_test, pred_lr))*100)
# Out:
# accuracy of the model = 96.29804898287668

# %%
cv_score=(cross_val_score(lr,X,y,cv=5).mean())*100
cv_score
# Out:
# 85.92145825803334

# %%
#importing necessary library
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Lasso

# %% [markdown]
# # 2) Lasso regression

# %%
from sklearn.linear_model import Lasso

parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 0}

# %%
ls=Lasso(alpha=0.0001,random_state=0)
ls.fit(x_train,y_train)
ls_score= ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
ls_score*100
# Out:
# 96.05068423919884

# %%
print("accuracy of the model =",(r2_score(y_test, pred_ls))*100)
ls_score*100
# Out:
# accuracy of the model = -6.544517876041889
# 96.05068423919884

# %%
cv_score=(cross_val_score(ls,X,y,cv=5).mean())*100
cv_score
# Out:
# 85.94068827272068

# %% [markdown]
# # 3)Ensemble technique

# %%
parameters={'criterion':['mse','mae','rms'],
           'max_features':["auto","sqrt","log2"]}

rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'auto'}

# %%
rf=RandomForestRegressor(criterion='mse',max_features='auto')
rf.fit(x_train,y_train)
rfs1=rf.score(x_train,y_train)
print(rfs1*100)
pred_test_rf=rf.predict(x_test)

rfs=r2_score(y_test, pred_test_rf)
print("R2 score :",rfs*100)


cv_score=(cross_val_score(ls,X,y,cv=5).mean())*100
print("cross val score",cv_score)
# Out:
# 94.3417675069705
# R2 score : -24.015673488867996
# cross val score 85.94068827272068

# %% [markdown]
# # 4) KNN regressor

# %%
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor()

# %%
from sklearn.model_selection import GridSearchCV
params = {'n_neighbors':[2,3,4,5,6,7,8,9]}

knn =KNeighborsRegressor()

model = GridSearchCV(knn, params, cv=5)
model.fit(x_train,y_train)
model.best_params_
# Out:
# {'n_neighbors': 9}

# %%
knn=KNeighborsRegressor(n_neighbors=9)
knn.fit(x_train,y_train)
knn.score(x_train,y_train)
pred_test_knn=knn.predict(x_test)

rfs=r2_score(y_test, pred_test_knn)
print("R2 score :",rfs*100)

cvscore=(cross_val_score(knn,X,y,cv=5))

print("cross val score",cvscore.mean()*100)
# Out:
# R2 score : 76.1192899676172
# cross val score -76.74168053173635

# %% [markdown]
# # 1)DecisionTreeRegressor

# %%
parameter={'max_depth':np.arange(2,50),
          'max_features':["auto","sqrt","log2"]}

dt=DecisionTreeRegressor()
clf=GridSearchCV(dt,parameter)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'max_depth': 10, 'max_features': 'auto'}

# %%
dt=DecisionTreeRegressor(max_depth=4,max_features='auto')

dt.fit(x_train,y_train)
dts1=dt.score(x_train,y_train)
print("training accuracy =",dts1*100)

pred_test_dt=dt.predict(x_test)

dts=r2_score(y_test, pred_test_dt)
print("R2 score :",dts*100)


dtscore=(cross_val_score(dt,X,y,cv=5).mean())*100
print("cross val score",dtscore)
# Out:
# training accuracy = 73.70152367180134
# R2 score : -98.2454773454936
# cross val score -76.41362653502684
